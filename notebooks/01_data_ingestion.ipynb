# %% [markdown]
# # Bluestock Fintech — Mutual Fund Analytics
# ## Day 3: Exploratory Data Analysis (EDA)
# **Intern:** Madhankumar V
# **Date:** June 2026
# **Data:** 40 funds | 46,000 NAV records | 32,778 transactions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
print("✅ Libraries loaded!")
# Out:
# ✅ Libraries loaded!

# %% [markdown]
# # Load all datasets
# import os
# os.chdir('..')  # Go up to project root
#
# df_nav   = pd.read_csv("data/processed/clean_nav.csv", parse_dates=['date'])
# df_fund  = pd.read_csv("data/processed/clean_fund_master.csv")
# df_aum   = pd.read_csv("data/processed/clean_aum.csv", parse_dates=['date'])
# df_sip   = pd.read_csv("data/processed/clean_sip.csv", parse_dates=['month'])
# df_tx    = pd.read_csv("data/processed/clean_transactions.csv")
# df_folio = pd.read_csv("data/processed/clean_folio_count.csv", parse_dates=['month'])
# df_hold  = pd.read_csv("data/processed/clean_portfolio_holdings.csv")
# df_perf  = pd.read_csv("data/processed/clean_performance.csv")
#
# print(f"✅ NAV records: {len(df_nav):,}")
# print(f"✅ Transactions: {len(df_tx):,}")
# print(f"✅ Funds: {len(df_fund)}")
# print(f"✅ All datasets loaded!")

# %% [markdown]
# ## Chart 1: NAV Trend Lines (2022–2026)
# Tracking daily NAV movement for selected funds across 4.5 years.

# %%
CHARTS_DIR = "reports/charts"

img = plt.imread(f"{CHARTS_DIR}/chart1_nav_trends.png")
plt.figure(figsize=(14,6))
plt.imshow(img)
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 2: AUM Growth by Fund House
# ## Chart 3: SIP Inflow Trend
# ## Chart 4: Category Heatmap
# ## Chart 5: Demographics
# ## Chart 6: Geographic Distribution
# ## Chart 7: Folio Count Growth
# ## Chart 8: Correlation Matrix
# ## Chart 9: Sector Allocation
# ## Chart 10: Payment Mode

# %%
charts = [
    ("chart2_aum_growth.png", "AUM Growth by Fund House"),
    ("chart3_sip_inflow.png", "SIP Inflow Trend"),
    ("chart4_category_heatmap.png", "Category Heatmap"),
    ("chart5_demographics.png", "Demographics"),
    ("chart6_geographic.png", "Geographic Distribution"),
    ("chart7_folio_growth.png", "Folio Count Growth"),
    ("chart8_correlation.png", "Correlation Matrix"),
    ("chart9_sector_allocation.png", "Sector Allocation"),
    ("chart10_payment_mode.png", "Payment Mode"),
    ("chart11_gender.png", "Gender Distribution"),
    ("chart12_monthly_volume.png", "Monthly Volume"),
    ("chart13_top_funds.png", "Top Performing Funds"),
    ("chart14_expense_ratio.png", "Expense Ratio"),
    ("chart15_kyc_risk.png", "KYC & Risk"),
]

for filename, title in charts:
    img = plt.imread(f"{CHARTS_DIR}/{filename}")
    plt.figure(figsize=(14, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    print(f"✅ {title}")
# Out:
# ✅ AUM Growth by Fund House
# ✅ SIP Inflow Trend
# ✅ Category Heatmap
# ✅ Demographics
# ✅ Geographic Distribution
# ✅ Folio Count Growth
# ✅ Correlation Matrix
# ✅ Sector Allocation
# ✅ Payment Mode
# ✅ Gender Distribution
# ✅ Monthly Volume
# ✅ Top Performing Funds
# ✅ Expense Ratio
# ✅ KYC & Risk

# %% [markdown]
# ## 📋 Key EDA Findings
#
# 1. **Small Cap funds outperform** — SBI Small Cap delivered 23.39% 3-year CAGR
# 2. **SIP inflows hit all-time high** — ₹31,002 Cr in Dec 2025, 3x growth since 2022
# 3. **T30 cities dominate** — 66.3% investments from Top 30 cities
# 4. **26-35 age group most active** — 13,463 transactions, highest among all groups
# 5. **UPI is preferred** — 55%+ transactions use UPI
# 6. **Equity funds costlier** — Avg expense ratio 1.34% vs 0.67% for Debt
# 7. **SBI dominates AUM** — ₹12.5 lakh crore, largest fund house
# 8. **High correlation among Large Cap** — 0.85+ correlation between funds
# 9. **92% investors KYC verified** — Strong compliance
# 10. **Folio count doubled** — 13.26 crore to 2
